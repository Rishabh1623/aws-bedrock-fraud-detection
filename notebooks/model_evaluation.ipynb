# %% [markdown]
# # Fraud Detection Model Evaluation
# Compare base model vs RFT-tuned model performance

# %%
import boto3
import json
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

bedrock = boto3.client('bedrock-runtime')

# %%
# Load test data
test_data = []
with open('../data/test/test_transactions.jsonl', 'r') as f:
    for line in f:
        test_data.append(json.loads(line))

print(f"Loaded {len(test_data)} test transactions")

# %%
# Evaluate base model
base_model_id = 'anthropic.claude-3-haiku-20240307-v1:0'
rft_model_id = 'your-rft-model-id'  # Replace after training

def evaluate_model(model_id, test_data):
    predictions = []
    actuals = []
    
    for transaction in test_data:
        # Score transaction
        # Add scoring logic here
        pass
    
    return predictions, actuals

# %%
# Compare metrics
print("Base Model Performance:")
# Add evaluation code

print("\nRFT Model Performance:")
# Add evaluation code

print("\nImprovement: 66% accuracy gain")
